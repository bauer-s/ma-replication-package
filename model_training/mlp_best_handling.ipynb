# %%
import joblib
import pickle

# %% [markdown]
# TODO: Load joblib from fitness and testoutcome and extract model

# %%
fitness_artifacts = joblib.load("mlp_best.joblib")

# %%
fitness_artifacts
# Out:
# {'best_params': {'activation': 'tanh',
#   'alpha': 1e-05,
#   'hidden_layer_sizes': (64, 128),
#   'learning_rate': 'constant',
#   'solver': 'adam'},
#  'best_score': np.float64(0.6388589630029404),
#  'scaler': StandardScaler(),
#  'model': MLPRegressor(activation='tanh', alpha=1e-05, early_stopping=True,
#               hidden_layer_sizes=(64, 128), max_iter=300, random_state=42)}

# %%
# Pickle the model to a file
pickle.dump(fitness_artifacts["model"], open("model_fitness.pickle", "wb"))
